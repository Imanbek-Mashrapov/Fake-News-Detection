# %%
from bs4 import BeautifulSoup 
import requests

# %%
url = "https://www.azattyk.org/"

page = requests.get(url)

soup = BeautifulSoup(page.text, "html")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="ky">
# <head>
# <link href="/Content/responsive/RFE/ky-KG/RFE-ky-KG.css?&amp;av=0.0.0.0&amp;cb=382" rel="stylesheet"/>
# <script src="https://tags.azattyk.org/rferl-pangea/prod/utag.sync.js"></script><script async="" src="https://www.youtube.com/iframe_api" type="text/javascript"></script> <link href="/manifest.json" rel="manifest"/>
# <script type="text/javascript">
#         //a general 'js' detection, must be on top level in <head>, due to CSS performance
#         document.documentElement.className = "js";
#         var cacheBuster = "382";
#         var appBaseUrl = "/";
#         var imgEnhancerBreakpoints = [0, 144, 256, 408, 650, 1023, 1597];
#         var isLoggingEnabled = false;
#         var isPreviewPage = false;
#         var isLivePreviewPage = false;
#
#         if (!isPreviewPage) {
#             window.RFE = window.RFE || {};
#             window.RFE.cacheEnabledByParam = window.location.href.indexOf('nocache=1') === -1;
#
#             const url = new URL(window.location.href);
#             const params = new URLSearchParams(url.search);
#
#             // Remove the 'nocache' parameter
#             params.delete('nocache');
#
#             // Update the URL without the 'nocache' parameter
#             url.search = params.toString();
#             window.history.replaceState(null, '', url.toString());
#         } else {
#             window.addEventListener('load', function() {
#                 const links = window.document.links;
#                 for (let i = 0; i < links.length; i++) {
#                     links[i].href = '#';
#                     links[i].target = '_self';
#                 }
#              })
#         }
#
#         // Iframe & Embed detection
#         var embedProperties = {};
#
#         try {
#             // Reliable way to check if we are in an iframe.
#             var isIframe = window.self !== window.top;
#             embedProperties.is_iframe = isIframe;
#
#             if (!isIframe) {
#                 embedProperties.embed_context = "main";
#             } else {
#                 // We are in an iframe. Let's try to access the parent.
#                 // This access will only fail with strict cross-origin (without document.domain).
#                 var parentLocation = window.top.location;
#
#                 // The access succeeded. Now we explicitly compare the hostname.
#                 if (window.location.hostname === parentLocation.hostname) {
#                     embedProperties.embed_context = "embed_self";
#                 } else {
#                     // Hostname is different (e.g. different subdomain with document.domain)
#                     embedProperties.embed_context = "embed_cross";
#                 }
#
#                 // Since the access works, we can safely get the details.
#                 embedProperties.url_parent = parentLocation.href;
#                 embedProperties.title_parent = window.top.document.title;
#             }
#         } catch (err) {
#             // We are in an iframe, and an error occurred, probably due to cross-origin restrictions.
#             embedProperties.is_iframe = true;
#             embedProperties.embed_context = "embed_cross";
#
#             // We cannot access the properties of window.top.
#             // `document.referrer` can sometimes provide the URL of the parent page.
#             // It is not 100% reliable, but it is the best we can do in this situation.
#             embedProperties.url_parent = document.referrer || null;
#             embedProperties.title_parent = null; // We can't get to the title in a cross-origin scenario.
#         }
#
# var pwaEnabled = false;        var swCacheDisabled;
#     </script>
# <meta charset="utf-8"/>
# <title>Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар</title>
# <meta content="“Азаттык үналгысы” – Кыргызстан жана дүйнө жаңылыктары, курч иликтөө, талкуу жана маектер, кызыктуу видео, фото жана аудиолорду сунуш кылган медиа мекеме. Биздин кабарчылар Бишкек, Ош, Жаалал-Абад, Ысык-Көл, Нарын, Талас, Баткен, Москва (Россия), Анкара (Түркия), Прага (Европа) жана башка шаарлардан маалымат беришет." name="description"/>
# <meta content="Азаттык, Азаттык үналгысы, Азаттык радиосу, Azattyk, Кыргызстан, жанылыктар, жаңылыктар, акыркы кабарлар, акыркы жаңылыктар, Азаттык новости, новость Кыргызстан, жаңылыктар, саясат, экономика, коом, турмуш, Азаттык онлайн, азаттык уналгысы, азаттык угуу, azattyk, акыркы кабарлар, акыркы жаңылыктар, жанылыктар,азаттык радио онлайн, азаттык онлайн, Кыргызстан радио, кыргызча радио, азаттык түз эфир, азаттык бугунку, новости, новости Кыргызстана, соңку кабар, Бишкек, Ош, " name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="max-image-preview:large" name="robots"/><meta content="132515023525838" property="fb:pages"/> <meta content="9f3418917dcb252c" name="yandex-verification"/>
# <link href="https://www.azattyk.org/" rel="canonical"/>
# <meta content="Азаттык" name="apple-mobile-web-app-title"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app-id=1521472502" name="apple-itunes-app"/>
# <meta content="Фейсбуктагы санариптик көрсөткүч:" property="fb:admins"/>
# <meta content="article" property="og:type"/>
# <meta content="Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар" property="og:title"/>
# <meta content="“Азаттык үналгысы” – Кыргызстан жана дүйнө жаңылыктары, курч иликтөө, талкуу жана маектер, кызыктуу видео, фото жана аудиолорду сунуш кылган медиа мекеме. Биздин кабарчылар Бишкек, Ош, Жаалал-Абад, Ысык-Көл, Нарын, Талас, Баткен, Москва (Россия), Анкара (Түркия), Прага (Европа) жана башка шаарлардан маалымат беришет." property="og:description"/>
# <meta content="https://www.azattyk.org/Content/responsive/RFE/ky-KG/img/top_logo_news.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="675" property="og:image:height"/>
# <meta content="site logo" property="og:image:alt"/>
# <meta content="https://www.azattyk.org/" property="og:url"/>
# <meta content="Азаттык Υналгысы" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@Azattyk_Radiosu" name="twitter:site"/>
# <meta content="p8kl0Zop45nBQaY1nuQ07qudwVMAsz08KQo6QCDoB90" name="google-site-verification"/><script type="application/ld+json">{"isAccessibleForFree":true,"headline":"Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар","inLanguage":"ky-KG","keywords":"Азаттык, Азаттык үналгысы, Азаттык радиосу, Azattyk, Кыргызстан, жанылыктар, жаңылыктар, акыркы кабарлар, акыркы жаңылыктар, Азаттык новости, новость Кыргызстан, жаңылыктар, саясат, экономика, коом, турмуш, Азаттык онлайн, азаттык уналгысы, азаттык угуу, azattyk, акыркы кабарлар, акыркы жаңылыктар, жанылыктар,азаттык радио онлайн, азаттык онлайн, Кыргызстан радио, кыргызча радио, азаттык түз эфир, азаттык бугунку, новости, новости Кыргызстана, соңку кабар, Бишкек, Ош, ","datePublished":"2026-05-04 18:24:25Z","dateModified":"2026-05-04 18:24:25Z","publisher":{"logo":{"width":512,"height":220,"@type":"ImageObject","url":"https://www.azattyk.org/Content/responsive/RFE/ky-KG/img/logo.png"},"@type":"Organization","url":"https://www.azattyk.org","sameAs":["https://www.facebook.com/azattyk.org","https://twitter.com/Azattyk_Radiosu","https://www.youtube.com/user/AzattykUnalgysy","https://telegram.me/Azattyk_radiosu","https://soundcloud.com/azattyk-audio","https://www.instagram.com/azattyk.kg/","https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E","https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E"],"name":"Азаттык Үналгысы | Кыргызстан: видео, фото, кабарлар","alternateName":""},"@context":"https://schema.org","@type":"WebSite","mainEntityOfPage":"https://www.azattyk.org/","url":"https://www.azattyk.org/","description":"“Азаттык үналгысы” – Кыргызстан жана дүйнө жаңылыктары, курч иликтөө, талкуу жана маектер, кызыктуу видео, фото жана аудиолорду сунуш кылган медиа мекеме. Биздин кабарчылар Бишкек, Ош, Жаалал-Абад, Ысык-Көл, Нарын, Талас, Баткен, Москва (Россия), Анкара (Түркия), Прага (Европа) жана башка шаарлардан маалымат беришет.","name":"Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар","potentialAction":{"target":"https://www.azattyk.org/s?k={search_term_string}","query-input":"required name=search_term_string","@type":"SearchAction"}}</script>
# <script src="/Scripts/responsive/infographics.bundle.min.js?&amp;av=0.0.0.0&amp;cb=382"></script>
# <script src="/Scripts/responsive/dollardom.min.js?&amp;av=0.0.0.0&amp;cb=382"></script>
# <script src="/Scripts/responsive/modules/commons.js?&amp;av=0.0.0.0&amp;cb=382"></script>
# <script src="/Scripts/responsive/modules/app_code.js?&amp;av=0.0.0.0&amp;cb=382"></script>
# <link href="/Content/responsive/RFE/img/webApp/favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="/Content/responsive/RFE/img/webApp/favicon.ico" rel="alternate icon"/>
# <link color="#ea6903" href="/Content/responsive/RFE/img/webApp/favicon_safari.svg" rel="mask-icon"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-57x57.png" rel="apple-touch-icon-precomposed"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-192x192.png" rel="icon" sizes="192x192"/>
# <link href="/Content/responsive/RFE/img/webApp/ico-128x128.png" rel="icon" sizes="128x128"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/Content/responsive/RFE/img/webApp/ico-144x144.png" name="msapplication-TileImage"/>
# <link as="font" crossorigin="anonymous" href="/Content/responsive/fonts/Skolar-Lt_Cyrl_v2.4.woff" rel="preload" type="font/woff"/>
# <link href="/api/" rel="alternate" title="RFE/RL - Top Stories [RSS]" type="application/rss+xml"/>
# <link href="/sitemap.xml" rel="sitemap" type="application/rss+xml"/>
# <script type="text/javascript">
#             var analyticsData = Object.assign(embedProperties, {url:"https://www.azattyk.org",property_id:"419",page_title:"Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар",page_type:"homepage",content_type:"index",subcontent_type:"homepage",last_modified:"2026-05-04 18:24:25Z",pub_datetime:"2016-04-27 00:00:00Z",section:"азаттык үналгысы | кыргызстан жана дүйнө: видео, фото, кабарлар",english_section:"azattyk-org-main-page",domain:"www.azattyk.org",language:"Kyrgyz",language_service:"RFERL Kyrgyz",platform:"web",copied:"no",copied_article:"",copied_title:"",runs_js:"Yes",cms_release:"8.46.0.0.382",enviro_type:"prod",slug:"azattyk-org-main-page",entity:"RFE",short_language_service:"KYR",platform_short:"W",page_name:"Азаттык Үналгысы | Кыргызстан жана дүйнө: видео, фото, кабарлар"});
#             // Push Analytics data as GTM message (without "event" attribute and before GTM initialization)
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push(analyticsData);
#         </script>
# <script data-cookiecategory="analytics" type="text/javascript">
#
#             var gtmEventObject = {event: 'page_meta_ready'};window.dataLayer = window.dataLayer || [];window.dataLayer.push(gtmEventObject);
#             var renderGtm = "true";
#             if (renderGtm === "true") {
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-WXZBPZ');
#             }
#         </script>
# </head>
# <body class="nav-no-loaded cc_theme pg-section pg-home nojs-images date-time-enabled">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WXZBPZ" style="display:none;visibility:hidden" width="0"></iframe></noscript> <script data-cookiecategory="analytics" type="text/javascript">
#
#             var gtmEventObject = {event: 'page_meta_ready'};window.dataLayer = window.dataLayer || [];window.dataLayer.push(gtmEventObject);
#
#             var renderGtm = "true";
#             if (renderGtm === "true") {
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-WXZBPZ');
#             }
#
#         </script>
# <!--Analytics tag js version start-->
# <script data-cookiecategory="analytics" type="text/javascript">
#                 var utag_data = Object.assign({}, analyticsData, {pub_year:"2016",pub_month:"04",pub_day:"27",pub_hour:"00",pub_weekday:"Wednesday"});
# if(typeof(TealiumTagFrom)==='function' && typeof(TealiumTagSearchKeyword)==='function') {
# var utag_from=TealiumTagFrom();var utag_searchKeyword=TealiumTagSearchKeyword();
# if(utag_searchKeyword!=null && utag_searchKeyword!=='' && utag_data["search_keyword"]==null) utag_data["search_keyword"]=utag_searchKeyword;if(utag_from!=null && utag_from!=='') utag_data["from"]=TealiumTagFrom();}
#                 if(window.top!== window.self&&utag_data.page_type==="snippet"){utag_data.page_type = 'iframe';}
#                 try{if(window.top!==window.self&&window.self.location.hostname===window.top.location.hostname){utag_data.platform = 'self-embed';utag_data.platform_short = 'se';}}catch(e){if(window.top!==window.self&&window.self.location.search.includes("platformType=self-embed")){utag_data.platform = 'cross-promo';utag_data.platform_short = 'cp';}}
#                 (function(a,b,c,d){    a="https://tags.azattyk.org/rferl-pangea/prod/utag.js";    b=document;c="script";d=b.createElement(c);d.src=a;d.type="text/java"+c;d.async=true;    a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);    })();
#             </script>
# <!--Analytics tag js version end-->
# <!-- Analytics tag management NoScript -->
# <noscript>
# <img alt="analytics" height="1" src="https://ssc.azattyk.org/b/ss/bbgprod,bbgentityrferl/1/G.4--NS/113836325?pageName=rfe%3akyr%3aw%3ahomepage%3a%d0%90%d0%b7%d0%b0%d1%82%d1%82%d1%8b%d0%ba%20%d2%ae%d0%bd%d0%b0%d0%bb%d0%b3%d1%8b%d1%81%d1%8b%20%7c%20%d0%9a%d1%8b%d1%80%d0%b3%d1%8b%d0%b7%d1%81%d1%82%d0%b0%d0%bd%20%d0%b6%d0%b0%d0%bd%d0%b0%20%d0%b4%d2%af%d0%b9%d0%bd%d3%a9%3a%20%d0%b2%d0%b8%d0%b4%d0%b5%d0%be%2c%20%d1%84%d0%be%d1%82%d0%be%2c%20%d0%ba%d0%b0%d0%b1%d0%b0%d1%80%d0%bb%d0%b0%d1%80&amp;c6=%d0%90%d0%b7%d0%b0%d1%82%d1%82%d1%8b%d0%ba%20%d2%ae%d0%bd%d0%b0%d0%bb%d0%b3%d1%8b%d1%81%d1%8b%20%7c%20%d0%9a%d1%8b%d1%80%d0%b3%d1%8b%d0%b7%d1%81%d1%82%d0%b0%d0%bd%20%d0%b6%d0%b0%d0%bd%d0%b0%20%d0%b4%d2%af%d0%b9%d0%bd%d3%a9%3a%20%d0%b2%d0%b8%d0%b4%d0%b5%d0%be%2c%20%d1%84%d0%be%d1%82%d0%be%2c%20%d0%ba%d0%b0%d0%b1%d0%b0%d1%80%d0%bb%d0%b0%d1%80&amp;v36=8.46.0.0.382&amp;v6=D=c6&amp;g=https%3a%2f%2fwww.azattyk.org&amp;c1=D=g&amp;v1=D=g&amp;events=event1&amp;c16=rferl%20kyrgyz&amp;v16=D=c16&amp;c5=azattyk-org-main-page&amp;v5=D=c5&amp;ch=%d0%90%d0%b7%d0%b0%d1%82%d1%82%d1%8b%d0%ba%20%d2%ae%d0%bd%d0%b0%d0%bb%d0%b3%d1%8b%d1%81%d1%8b%20%7c%20%d0%9a%d1%8b%d1%80%d0%b3%d1%8b%d0%b7%d1%81%d1%82%d0%b0%d0%bd%20%d0%b6%d0%b0%d0%bd%d0%b0%20%d0%b4%d2%af%d0%b9%d0%bd%d3%a9%3a%20%d0%b2%d0%b8%d0%b4%d0%b5%d0%be%2c%20%d1%84%d0%be%d1%82%d0%be%2c%20%d0%ba%d0%b0%d0%b1%d0%b0%d1%80%d0%bb%d0%b0%d1%80&amp;c15=kyrgyz&amp;v15=D=c15&amp;c4=index&amp;v4=D=c4&amp;v20=no&amp;c17=web&amp;v17=D=c17&amp;mcorgid=518abc7455e462b97f000101%40adobeorg&amp;server=www.azattyk.org&amp;pageType=D=c4&amp;ns=bbg&amp;v29=D=server&amp;v25=rfe&amp;v30=419&amp;v105=D=User-Agent " style="position: absolute; border: none;" width="1"/></noscript>
# <!-- End of Analytics tag management NoScript -->
# <!--*** Accessibility links - For ScreenReaders only ***-->
# <section>
# <div class="sr-only">
# <h2>Линктер </h2>
# <ul>
# <li><a data-disable-smooth-scroll="1" href="#content">Мазмунга өтүңүз</a></li>
# <li><a data-disable-smooth-scroll="1" href="#navigation">Навигацияга өтүңүз</a></li>
# <li><a data-disable-smooth-scroll="1" href="#txtHeaderSearch">Издөөгө салыңыз</a></li>
# </ul>
# </div>
# </section>
# <div dir="ltr">
# <div id="page">
# <aside>
# <div class="ctc-message pos-fix">
# <div class="ctc-message__inner">Шилтеме көчүрүлдү</div>
# </div>
# </aside>
# <div class="hdr-20 hdr-20--big">
# <div class="hdr-20__inner">
# <div class="hdr-20__max pos-rel">
# <div class="hdr-20__side hdr-20__side--primary d-flex">
# <label class="burger hdr-trigger pos-rel trans-trigger" data-for="main-menu-ctrl" data-switch-target="main-menu-ctrl" data-switcher-trigger="true" data-trans-evt="click" data-trans-id="menu">
# <span class="ico ico-close hdr-trigger__ico hdr-trigger__ico--close burger__ico burger__ico--close"></span>
# <span class="ico ico-menu hdr-trigger__ico hdr-trigger__ico--open burger__ico burger__ico--open"></span>
# </label>
# <div class="menu-pnl pos-fix trans-target" data-switch-target="main-menu-ctrl" data-trans-id="menu">
# <div class="menu-pnl__inner">
# <nav class="main-nav menu-pnl__item menu-pnl__item--first">
# <ul class="main-nav__list accordeon" data-analytics-tales="false" data-location-name="nav,secnav" data-promo-name="link">
# <li class="main-nav__item">
# <a class="main-nav__item-name main-nav__item-name--link" data-item-name="ky-news" href="/news" title="Жаңылыктар">Жаңылыктар</a>
# </li>
# <li class="main-nav__item accordeon__item" data-switch-target="menu-item-960">
# <label class="main-nav__item-name main-nav__item-name--label accordeon__control-label" data-for="menu-item-960" data-switcher-trigger="true">
#                 Кыргызстан
#                 <span class="ico ico-chevron-down main-nav__chev"></span>
# </label>
# <div class="main-nav__sub-list">
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="kyrgyzstan" href="/Kyrgyzstan" title="Кыргызстан">Кыргызстан</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="saiasat" href="/politics" title="Саясат">Саясат</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="ky-economy" href="/economics" title="Экономика">Экономика</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="ky-culture" href="/culture" title="маданият">маданият</a>
# </div>
# </li>
# <li class="main-nav__item accordeon__item" data-switch-target="menu-item-1030">
# <label class="main-nav__item-name main-nav__item-name--label accordeon__control-label" data-for="menu-item-1030" data-switcher-trigger="true">
#                 Дүйнө
#                 <span class="ico ico-chevron-down main-nav__chev"></span>
# </label>
# <div class="main-nav__sub-list">
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="ky-world" href="/world" title="Дүйнө">Дүйнө</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="ky-central_asia" href="/central-asia" title="Борбор Азия">Борбор Азия</a>
# </div>
# </li>
# <li class="main-nav__item">
# <a class="main-nav__item-name main-nav__item-name--link" data-item-name="war-in-ukraine" href="/p/8776.html" title="Украина">Украина</a>
# </li>
# <li class="main-nav__item">
# <a class="main-nav__item-name main-nav__item-name--link" data-item-name="ky-special-investiagiton" href="/investigation" title="Атайын иликтөө">Атайын иликтөө</a>
# </li>
# <li class="main-nav__item accordeon__item" data-switch-target="menu-item-2922">
# <label class="main-nav__item-name main-nav__item-name--label accordeon__control-label" data-for="menu-item-2922" data-switcher-trigger="true">
#                 ТВ программалар
#                 <span class="ico ico-chevron-down main-nav__chev"></span>
# </label>
# <div class="main-nav__sub-list">
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="world-news" href="/z/17386" title="Бүгүн Азаттыкта">Бүгүн Азаттыкта</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="experts_analyze" href="/ExpertterTV" title="Эксперттер талдайт">Эксперттер талдайт</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="world-and-us-tv" href="/DuinoTV" title="Биз жана дүйнө">Биз жана дүйнө</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="daniste" href="/DanisteTV" title="Данисте">Данисте</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="sisterhood" href="/EjeSingdiTV" title="Эже-сиңдилер">Эже-сиңдилер</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="Azattyk_plus_TV" href="/PlusTV" title="Азаттык+">Азаттык+</a>
# <a class="main-nav__item-name main-nav__item-name--link main-nav__item-name--sub" data-item-name="Inconvenient__Questions_tv" href="/YngaisyzTV" title="Ыңгайсыз суроолор">Ыңгайсыз суроолор</a>
# </div>
# </li>
# <li class="main-nav__item">
# <a class="main-nav__item-name main-nav__item-name--link" data-item-name="azattyk-podcast" href="/p/7880.html" title="Подкаст">Подкаст</a>
# </li>
# <li class="main-nav__item">
# <a class="main-nav__item-name main-nav__item-name--link" data-item-name="blog--minsanat" href="/opinions" title="Өзгөчө пикир">Өзгөчө пикир</a>
# </li>
# </ul>
# </nav>
# <div class="menu-pnl__item">
# <a alt="Русский" class="menu-pnl__item-link" href="https://rus.azattyk.org">Русский</a>
# </div>
# <div class="menu-pnl__item menu-pnl__item--social">
# <h5 class="menu-pnl__sub-head">Онлайн шерине</h5>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-facebook" data-analytics-text="follow_on_facebook" href="https://www.facebook.com/azattyk.org" rel="noopener" target="_blank" title="Фейсбуктан караңыз">
# <span class="ico ico-facebook-alt ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-youtube" data-analytics-text="follow_on_youtube" href="https://www.youtube.com/user/AzattykUnalgysy" rel="noopener" target="_blank" title="Ютубдан көрүңүз">
# <span class="ico ico-youtube ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-twitter" data-analytics-text="follow_on_twitter" href="https://twitter.com/Azattyk_Radiosu" rel="noopener" target="_blank" title="Твиттерден караңыз">
# <span class="ico ico-twitter ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-instagram" data-analytics-text="follow_on_instagram" href="https://www.instagram.com/azattyk.kg/" rel="noopener" target="_blank" title="Инстаграмдан көрүңүз">
# <span class="ico ico-instagram ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-telegram" data-analytics-text="follow_on_telegram" href="https://telegram.me/Azattyk_radiosu" rel="noopener" target="_blank" title="Телеграмдан окуңуз">
# <span class="ico ico-telegram ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-g-news" data-analytics-text="follow_on_google_news" href="https://news.google.com/publications/CAAqBwgKMMH4gQIwvrcX?hl=ru&amp; " rel="noopener" target="_blank" title="Google News аркылуу окуңуз">
# <span class="ico ico-google-news ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-whatsapp visible-xs-inline-block visible-sm-inline-block" data-analytics-text="follow_on_whatsapp" href="https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E" rel="noopener" target="_blank" title="Follow on WhatsApp">
# <span class="ico ico-whatsapp ico--rounded"></span>
# </a>
# <a class="btn btn--rounded btn--social-inverted menu-pnl__btn js-social-btn btn-whatsapp visible-md-inline-block visible-lg-inline-block" data-analytics-text="follow_on_whatsapp_desktop" href="https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E" rel="noopener" target="_blank" title="Follow on WhatsApp">
# <span class="ico ico-whatsapp ico--rounded"></span>
# </a>
# </div>
# <div class="menu-pnl__item">
# <a class="menu-pnl__item-link" href="/navigation/allsites">
# <span class="ico ico-languages"></span>
#                                     ЭЕ/АРнун бардык сайттары
#                                 </a>
# </div>
# </div>
# </div>
# <label class="top-srch-trigger hdr-trigger" data-for="top-search-ctrl" data-switch-target="top-search-ctrl" data-switcher-trigger="true">
# <span class="ico ico-close hdr-trigger__ico hdr-trigger__ico--close top-srch-trigger__ico top-srch-trigger__ico--close"></span>
# <span class="ico ico-search hdr-trigger__ico hdr-trigger__ico--open top-srch-trigger__ico top-srch-trigger__ico--open"></span>
# </label>
# <div class="srch-top srch-top--in-header" data-switch-target="top-search-ctrl">
# <div class="container">
# <form action="/s" class="srch-top__form srch-top__form--in-header" id="form-topSearchHeader" method="get" role="search"> <label class="sr-only" for="txtHeaderSearch">Издөө</label>
# <input accesskey="s" class="srch-top__input analyticstag-event" id="txtHeaderSearch" name="k" onkeydown="if (event.keyCode === 13) { FireAnalyticsTagEventOnSearch('search', $dom.get('#txtHeaderSearch')[0].value) }" placeholder="Текст издөө" type="text" value=""/>
# <button class="btn btn--top-srch analyticstag-event" onclick="FireAnalyticsTagEventOnSearch('search', $dom.get('#txtHeaderSearch')[0].value) " title="Издөө" type="submit">
# <span class="ico ico-search"></span>
# </button>
# </form>
# </div>
# </div>
# <a class="main-logo-link" href="/">
# <img alt="site logo" class="main-logo main-logo--comp" src="/Content/responsive/RFE/ky-KG/img/logo-compact.svg?cb=382"/>
# <img alt="site logo" class="main-logo main-logo--big" src="/Content/responsive/RFE/ky-KG/img/logo.svg?cb=382"/>
# </a>
# </div>
# <div class="hdr-20__side hdr-20__side--secondary d-flex">
# <a class="hdr-20__secondary-item hdr-20__secondary-item--search" data-item-name="search" href="/s" title="Издөө">
# <span class="ico ico-search hdr-20__secondary-icon hdr-20__secondary-icon--search"></span>
# </a>
# <div class="srch-bottom">
# <form action="/s" class="srch-bottom__form d-flex" id="form-bottomSearch" method="get" role="search"> <label class="sr-only" for="txtSearch">Издөө</label>
# <input accesskey="s" class="srch-bottom__input analyticstag-event" id="txtSearch" name="k" onkeydown="if (event.keyCode === 13) { FireAnalyticsTagEventOnSearch('search', $dom.get('#txtSearch')[0].value) }" placeholder="Текст издөө" type="search" value=""/>
# <button class="btn btn--bottom-srch analyticstag-event" onclick="FireAnalyticsTagEventOnSearch('search', $dom.get('#txtSearch')[0].value) " title="Издөө" type="submit">
# <span class="ico ico-search"></span>
# </button>
# </form>
# </div>
# </div>
# <img alt="site logo" class="logo-print" loading="lazy" src="/Content/responsive/RFE/ky-KG/img/logo-print.gif?cb=382"/>
# <img alt="site logo" class="logo-print logo-print--color" loading="lazy" src="/Content/responsive/RFE/ky-KG/img/logo-print_color.png?cb=382"/>
# </div>
# </div>
# </div>
# <script>
#         if (document.body.className.indexOf('pg-home') > -1) {
#             var nav2In = document.querySelector('.hdr-20__inner');
#             var nav2Sec = document.querySelector('.hdr-20__side--secondary');
#             var secStyle = window.getComputedStyle(nav2Sec);
#             if (nav2In && window.pageYOffset < 150 && secStyle['position'] !== 'fixed') {
#                 nav2In.classList.add('hdr-20__inner--big')
#             }
#         }
#     </script>
# <div class="c-hlights c-hlights--breaking c-hlights--no-item" data-hlight-display="mobile,desktop">
# <div class="c-hlights__wrap container p-0">
# <div class="c-hlights__nav">
# <a href="#" role="button" title="Артка">
# <span class="ico ico-chevron-backward m-0"></span>
# <span class="sr-only">Артка</span>
# </a>
# <a href="#" role="button" title="Алдыга">
# <span class="ico ico-chevron-forward m-0"></span>
# <span class="sr-only">Алдыга</span>
# </a>
# </div>
# <span class="c-hlights__label">
# <span class="">ЧУКУЛ КАБАР!</span>
# <span class="switcher-trigger">
# <label class="switcher-trigger__label switcher-trigger__label--more p-b-0" data-for="more-less-1" data-switcher-trigger="true" title="Толук көрсөт">
# <span class="ico ico-chevron-down"></span>
# </label>
# <label class="switcher-trigger__label switcher-trigger__label--less p-b-0" data-for="more-less-1" data-switcher-trigger="true" title="Кыскарт">
# <span class="ico ico-chevron-up"></span>
# </label>
# </span>
# </span>
# <ul class="c-hlights__items switcher-target" data-switch-target="more-less-1">
# </ul>
# </div>
# </div>
# <div class="sub-nav container">
# <div class="sub-nav__inner">
# <a class="sub-nav__link" href="/AzattykTV" title="АЗАТТЫК ТВ">АЗАТТЫК ТВ</a>
# <a class="sub-nav__link" href="/azattyk-focus" title="ДҮЙНӨ">ДҮЙНӨ</a>
# <a class="sub-nav__link" href="/Kyrgyzstan" title="КЫРГЫЗСТАН">КЫРГЫЗСТАН</a>
# <a class="sub-nav__link" href="/p/8776.html" title="УКРАИНА">УКРАИНА</a>
# <a class="sub-nav__link" href="/p/7880.html" title="ПОДКАСТ">ПОДКАСТ</a>
# </div>
# </div>
# <div class="date-time-area">
# <div class="container">
# <span class="date-time">
#                 5-Май, 2026-жыл, шейшемби, Бишкек убактысы 00:24
#             </span>
# </div>
# </div>
# <div id="content">
# <div class="container" id="wrowblock-12173_75">
# <div class="row" id="wrowblock-12173_57">
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-12173_58">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12173_59">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12173_60">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-56237_9">
# <div class="row" id="wrowblock-56237_10">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-3c" id="wrowblock-56237_11">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-56241_9">
# <div class="row" id="wrowblock-56241_10">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-3c" id="wrowblock-56241_11">
# <div class="media-block-wrap" data-area-id="R3_1" id="wrowblock-56241_12">
# <div class="row">
# <ul class="list-w-vert">
# <li class="col-xs-12 col-sm-12 col-md-4 col-lg-4 list-w-vert__item list-w-vert__item--3c">
# <div class="media-block list-w-vert__mb list-w-vert__mb--3c">
# <div class="media-block__content">
# <a href="/a/33749637.html">
# <h4 class="media-block__title media-block__title--size-2" title="Ормуз кысыгындагы абал курч бойдон экени кабарланды">
#             Ормуз кысыгындагы абал курч бойдон экени кабарланды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-4 col-lg-4 list-w-vert__item list-w-vert__item--3c">
# <div class="media-block list-w-vert__mb list-w-vert__mb--3c">
# <div class="media-block__content">
# <a href="/a/33748687.html">
# <h4 class="media-block__title media-block__title--size-2" title="Арменияда 30дан ашуун европалык жана башка лидерлер чогулду">
#             Арменияда 30дан ашуун европалык жана башка лидерлер чогулду
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-4 col-lg-4 list-w-vert__item list-w-vert__item--3c">
# <div class="media-block list-w-vert__mb list-w-vert__mb--3c">
# <div class="media-block__content">
# <a href="/a/33748519.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Камбар-Ата 1": Өкмөттүк макулдашуу долбоору Ташкентте талкууланды'>
#             "Камбар-Ата 1": Өкмөттүк макулдашуу долбоору Ташкентте талкууланды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-56072_13">
# <div class="row" id="wrowblock-56072_14">
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56072_15">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56072_16">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56072_17">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-55498_73">
# <div class="row" id="wrowblock-55498_49">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-55498_50">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-12171_135">
# <div class="row" id="wrowblock-12171_136">
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-12171_137">
# <div class="media-block-wrap" data-area-id="R6_1" id="wrowblock-12171_140">
# <h2 class="section-head">
# <a href="/z/15817"><span class="ico ico-chevron-forward pull-right flip"></span>Башкы темалар</a></h2>
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12">
# <div class="media-block media-block--io media-block--t-spac">
# <a class="img-wrap img-wrap--size-1" href="/a/33748741.html" title="Басма сөз эркиндиги: Кыргызстан бир жылда эки баскычка төмөндөдү">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Бишкек. Сөз эркиндигин талап кылган акциялардын биринде. Архив." src="https://gdb.rferl.org/034d0000-0aff-0242-fae2-08dacede6477_cx0_cy18_cw0_w250_r1.png"/>
# </noscript>
# <img alt="Бишкек. Сөз эркиндигин талап кылган акциялардын биринде. Архив." class="" data-src="https://gdb.rferl.org/034d0000-0aff-0242-fae2-08dacede6477_cx0_cy18_cw0_w250_r1.png" src=""/>
# </div>
# </a>
# <div class="media-block__content img-overlay">
# <a href="/a/33748741.html">
# <h4 class="media-block__title media-block__title--size-1 media-block__title--io" title="Басма сөз эркиндиги: Кыргызстан бир жылда эки баскычка төмөндөдү">
#             Басма сөз эркиндиги: Кыргызстан бир жылда эки баскычка төмөндөдү
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media-block-wrap" data-area-id="R6_2" id="wrowblock-12171_141">
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-6 col-md-6 col-lg-6 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33749051.html" title='"Кызыл аянтка да жетет деп коркуп жатышат". Кремлге жакын жерге дрон тийди'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Москвадагы көп кабаттуу турак жайга дрон тийди. 4-май 2026-жыл" src="https://gdb.rferl.org/70c4df4d-2767-4db7-0694-08de3c642a38_w160_r1.jpg"/>
# </noscript>
# <img alt="Москвадагы көп кабаттуу турак жайга дрон тийди. 4-май 2026-жыл" class="" data-src="https://gdb.rferl.org/70c4df4d-2767-4db7-0694-08de3c642a38_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33749051.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Кызыл аянтка да жетет деп коркуп жатышат". Кремлге жакын жерге дрон тийди'>
#             "Кызыл аянтка да жетет деп коркуп жатышат". Кремлге жакын жерге дрон тийди
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-6 col-lg-6 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33748711.html" title="Ормуз кризиси: Трамптын гуманитардык операциясы, Ирандын жообу">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Ормуз кысыгындагы кемелер. 29-апрель, 2026-жыл" src="https://gdb.rferl.org/4338ef58-e6ac-4fd0-8e75-9c463514b989_w160_r1.jpg"/>
# </noscript>
# <img alt="Ормуз кысыгындагы кемелер. 29-апрель, 2026-жыл" class="" data-src="https://gdb.rferl.org/4338ef58-e6ac-4fd0-8e75-9c463514b989_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33748711.html">
# <h4 class="media-block__title media-block__title--size-2" title="Ормуз кризиси: Трамптын гуманитардык операциясы, Ирандын жообу">
#             Ормуз кризиси: Трамптын гуманитардык операциясы, Ирандын жообу
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12171_138">
# <div class="media-block-wrap" data-area-id="R6_3" id="wrowblock-12171_142">
# <h2 class="section-head">
# <a href="/news"><span class="ico ico-chevron-forward pull-right flip"></span>Жаңылыктар</a></h2>
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33749056.html">
# <h4 class="media-block__title media-block__title--size-4" title="ЖМК: Путин айланасындагы адамдардан чочулоодо">
#             ЖМК: Путин айланасындагы адамдардан чочулоодо
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33749647.html">
# <h4 class="media-block__title media-block__title--size-4" title="Орусияда чет өлкөлүктөргө мамлекеттик төлөмдөрдү жогорулатуу сунушталды">
#             Орусияда чет өлкөлүктөргө мамлекеттик төлөмдөрдү жогорулатуу сунушталды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748946.html">
# <h4 class="media-block__title media-block__title--size-4" title="Орус армиясынын аба соккусунан Харьковдо алты киши мүрт кетти">
#             Орус армиясынын аба соккусунан Харьковдо алты киши мүрт кетти
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748685.html">
# <h4 class="media-block__title media-block__title--size-4" title="Өкмөттө жер-жерлердеги соңку сел кырсыктары талкууланды ">
#             Өкмөттө жер-жерлердеги соңку сел кырсыктары талкууланды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748675.html">
# <h4 class="media-block__title media-block__title--size-4" title="Тажикстанда сел төрт кишинин өмүрүн алды">
#             Тажикстанда сел төрт кишинин өмүрүн алды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748665.html">
# <h4 class="media-block__title media-block__title--size-4" title='Өкмөт "Бала ырысы" жөлөкпулу үчүн 3 млрд сомдон ашык каражат бөлөт'>
#             Өкмөт "Бала ырысы" жөлөкпулу үчүн 3 млрд сомдон ашык каражат бөлөт
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748651.html">
# <h4 class="media-block__title media-block__title--size-4" title="Кыргызстан Сейшел аралдары менен визасыз каттам тууралуу макулдашты">
#             Кыргызстан Сейшел аралдары менен визасыз каттам тууралуу макулдашты
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748639.html">
# <h4 class="media-block__title media-block__title--size-4" title="Чаткал–Ала-Бука жолуна таш түшүп, каттам жабылды">
#             Чаткал–Ала-Бука жолуна таш түшүп, каттам жабылды
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12 mb-grid">
# <div class="media-block">
# <div class="media-block__content">
# <a href="/a/33748627.html">
# <h4 class="media-block__title media-block__title--size-4" title="Москвада көп кабаттуу үйгө дрон тийди">
#             Москвада көп кабаттуу үйгө дрон тийди
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <a class="link-more" href="/news">Бардык жаңылыктар</a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12171_139">
# <div class="media-block-wrap" data-area-id="R6_4" id="wrowblock-12171_143">
# <h2 class="section-head">
# <a href="/AzattykTV"><span class="ico ico-chevron-forward pull-right flip"></span>Азаттык ТВ</a></h2>
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12">
# <div class="media-block media-block--io media-block--t-spac">
# <a class="img-wrap img-wrap--size-1" href="/a/33748907.html" title="Тажикстан: Төрт өмүрдү жалмаган каргаша">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Тажикстан: Төрт өмүрдү жалмаган каргаша" src="https://gdb.rferl.org/f0ea3a0f-7541-4699-6005-08de3c91433d_tv_w250_r1.jpg"/>
# </noscript>
# <img alt="Тажикстан: Төрт өмүрдү жалмаган каргаша" class="" data-src="https://gdb.rferl.org/f0ea3a0f-7541-4699-6005-08de3c91433d_tv_w250_r1.jpg" src=""/>
# </div>
# <span class="ico ico-video ico--media-type"></span> </a>
# <div class="media-block__content img-overlay">
# <a href="/a/33748907.html">
# <h4 class="media-block__title media-block__title--size-1 media-block__title--io" title="Тажикстан: Төрт өмүрдү жалмаган каргаша">
#             Тажикстан: Төрт өмүрдү жалмаган каргаша
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media-block-wrap" data-area-id="R6_5" id="wrowblock-12171_144">
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12">
# <div class="media-block media-block--io media-block--t-spac">
# <a class="img-wrap img-wrap--size-1" href="/a/33747629.html" title="Милянфан: дунган тою, салты жана тили">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Милянфан: дунган тою, салты жана тили" src="https://gdb.rferl.org/cf6e1157-43d9-4431-daa3-08de3c914337_w250_r1.png"/>
# </noscript>
# <img alt="Милянфан: дунган тою, салты жана тили" class="" data-src="https://gdb.rferl.org/cf6e1157-43d9-4431-daa3-08de3c914337_w250_r1.png" src=""/>
# </div>
# <span class="ico ico-video ico--media-type"></span> </a>
# <div class="media-block__content img-overlay">
# <a href="/a/33747629.html">
# <h4 class="media-block__title media-block__title--size-1 media-block__title--io" title="Милянфан: дунган тою, салты жана тили">
#             Милянфан: дунган тою, салты жана тили
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media-block-wrap" data-area-id="R6_6" id="wrowblock-12171_145">
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-12 col-md-12 col-lg-12">
# <div class="media-block media-block--io media-block--t-spac">
# <a class="img-wrap img-wrap--size-1" href="/a/33746386.html" title="Евробиримдиктин санкциясы Кыргызстанга эмнеге кооптуу?">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Евробиримдиктин санкциясы Кыргызстанга эмнеге кооптуу?" src="https://gdb.rferl.org/362c11a2-3075-4073-060d-08de3c642a38_tv_w250_r1.jpg"/>
# </noscript>
# <img alt="Евробиримдиктин санкциясы Кыргызстанга эмнеге кооптуу?" class="" data-src="https://gdb.rferl.org/362c11a2-3075-4073-060d-08de3c642a38_tv_w250_r1.jpg" src=""/>
# </div>
# <span class="ico ico-video ico--media-type"></span> </a>
# <div class="media-block__content img-overlay">
# <a href="/a/33746386.html">
# <h4 class="media-block__title media-block__title--size-1 media-block__title--io" title="Евробиримдиктин санкциясы Кыргызстанга эмнеге кооптуу?">
#             Евробиримдиктин санкциясы Кыргызстанга эмнеге кооптуу?
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wg-hlight" id="wrowblock-61060_45">
# <div class="container" id="wrowblock-61060_46">
# </div>
# </div>
# <div class="container" id="wrowblock-61061_73">
# <div class="row" id="wrowblock-61061_49">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-61061_50">
# <div class="media-block-wrap" data-area-id="R8_1" id="wrowblock-61061_51">
# <h2 class="section-head">
# Көңүл чордонунда</h2>
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33746107.html" title='Согушка айдалган мигранттар, санкциялар, туткундар... Украин элчисинин "Азаттыкка" маеги'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Валерий Жовтенко " src="https://gdb.rferl.org/46a2ea5d-53c9-43a7-6022-08de3c91433d_w160_r1.jpg"/>
# </noscript>
# <img alt="Валерий Жовтенко " class="" data-src="https://gdb.rferl.org/46a2ea5d-53c9-43a7-6022-08de3c91433d_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33746107.html">
# <h4 class="media-block__title media-block__title--size-2" title='Согушка айдалган мигранттар, санкциялар, туткундар... Украин элчисинин "Азаттыкка" маеги'>
#             Согушка айдалган мигранттар, санкциялар, туткундар... Украин элчисинин "Азаттыкка" маеги
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33748078.html" title='"Жер кыртышы бузулууда". Сел каптаган аймактар, өкмөттөгү жыйын'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Баткен облусу. Сел жүргөн аймак. Май, 2026-жыл " src="https://gdb.rferl.org/1b8eb5ab-1f71-4612-da9e-08de3c914337_cx0_cy14_cw0_w160_r1.jpg"/>
# </noscript>
# <img alt="Баткен облусу. Сел жүргөн аймак. Май, 2026-жыл " class="" data-src="https://gdb.rferl.org/1b8eb5ab-1f71-4612-da9e-08de3c914337_cx0_cy14_cw0_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33748078.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Жер кыртышы бузулууда". Сел каптаган аймактар, өкмөттөгү жыйын'>
#             "Жер кыртышы бузулууда". Сел каптаган аймактар, өкмөттөгү жыйын
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33745847.html" title='"Жардам бербей эле түздөп, талкалап жатабыз". Ысык-Көл экосистемасы, адистин пикири'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Ысык-Көл." src="https://gdb.rferl.org/083d0000-0a00-0242-62a2-08da356e019e_cx0_cy3_cw0_w160_r1.jpeg"/>
# </noscript>
# <img alt="Ысык-Көл." class="" data-src="https://gdb.rferl.org/083d0000-0a00-0242-62a2-08da356e019e_cx0_cy3_cw0_w100_r1.jpeg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33745847.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Жардам бербей эле түздөп, талкалап жатабыз". Ысык-Көл экосистемасы, адистин пикири'>
#             "Жардам бербей эле түздөп, талкалап жатабыз". Ысык-Көл экосистемасы, адистин пикири
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/33746027.html" title='"Ташы өйдө кулаган" Туманбаев, ишкана-мекемелерди "жуткан" Иш башкармалык '>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt='Президенттин иш башкаруучусу Каныбек Туманбаев. Артында президент Садыр Жапаров жана Туманбаев. "Азаттыктын" коллажы.' src="https://gdb.rferl.org/e2e37e67-ed38-4044-1d6f-08de3bed1b27_w160_r1.jpg"/>
# </noscript>
# <img alt='Президенттин иш башкаруучусу Каныбек Туманбаев. Артында президент Садыр Жапаров жана Туманбаев. "Азаттыктын" коллажы.' class="" data-src="https://gdb.rferl.org/e2e37e67-ed38-4044-1d6f-08de3bed1b27_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/33746027.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Ташы өйдө кулаган" Туманбаев, ишкана-мекемелерди "жуткан" Иш башкармалык '>
#             "Ташы өйдө кулаган" Туманбаев, ишкана-мекемелерди "жуткан" Иш башкармалык
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="fredContent" id="wrowblock-58172_42">
# <div class="fredContent__bg fredContent__bg--light" data-area-id="R9_1" id="wrowblock-58172_44">
# <div class="container">
# <h2 class="section-head">
# <a href="/azattyk-focus"><span class="ico ico-chevron-forward pull-right flip"></span>Дүйнө "Азаттыктын" назарында</a></h2>
# <div class="fredContent__controls">
# <div class="fredContent__controls-inner">
# ...
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-12764_50">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-12591_73">
# <div class="row" id="wrowblock-12591_49">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-12591_50">
# <div class="media-block-wrap" data-area-id="R28_1" id="wrowblock-12591_51">
# <h2 class="section-head">
# <a href="/culture"><span class="ico ico-chevron-forward pull-right flip"></span>Маданият</a></h2>
# <div class="row">
# <ul>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/kyrgyz-koruuchunun-tabiti-zhana-talaby/33734645.html" title="Жин-шайтан, мастан жана мушташ. Кыргыз көрүүчүнүн табити жана талабы">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Соңку жылдары тартылган кыргыз кинолору. (коллаж)" src="https://gdb.rferl.org/f4ae0f70-5e8e-42ad-0476-08de3c642a38_w160_r1.jpg"/>
# </noscript>
# <img alt="Соңку жылдары тартылган кыргыз кинолору. (коллаж)" class="" data-src="https://gdb.rferl.org/f4ae0f70-5e8e-42ad-0476-08de3c642a38_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/kyrgyz-koruuchunun-tabiti-zhana-talaby/33734645.html">
# <h4 class="media-block__title media-block__title--size-2" title="Жин-шайтан, мастан жана мушташ. Кыргыз көрүүчүнүн табити жана талабы">
#             Жин-шайтан, мастан жана мушташ. Кыргыз көрүүчүнүн табити жана талабы
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/instituttagy-tiresh-karmalgan-studentter/33741551.html" title='"Музыкалык деген сөз калсын". Институттагы тиреш, кармалган студенттер'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Бишкектеги Таштан Эрматов атындагы музыкалык-педагогикалык институттун студенттери. (коллаж)" src="https://gdb.rferl.org/bb054557-4182-4a99-1c47-08de3bed1b27_w160_r1.jpg"/>
# </noscript>
# <img alt="Бишкектеги Таштан Эрматов атындагы музыкалык-педагогикалык институттун студенттери. (коллаж)" class="" data-src="https://gdb.rferl.org/bb054557-4182-4a99-1c47-08de3bed1b27_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/instituttagy-tiresh-karmalgan-studentter/33741551.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Музыкалык деген сөз калсын". Институттагы тиреш, кармалган студенттер'>
#             "Музыкалык деген сөз калсын". Институттагы тиреш, кармалган студенттер
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/mafiya-cinema-ulan-egizbaev/33738107.html" title='"Мафия": Көкжал журналист, "көлөкөдөгү кардинал"'>
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt='"Мафия" тасмасында Уланбек Эгизбаевдин ролун жараткан актер Бакболот Коңурбаев (оңдо) жана Али Токтакуновду ойногон Баястан Колдошалы (солдо).' src="https://gdb.rferl.org/a7c1a60b-474b-42ef-4a05-08de3c92853e_cx0_cy2_cw0_w160_r1.jpg"/>
# </noscript>
# <img alt='"Мафия" тасмасында Уланбек Эгизбаевдин ролун жараткан актер Бакболот Коңурбаев (оңдо) жана Али Токтакуновду ойногон Баястан Колдошалы (солдо).' class="" data-src="https://gdb.rferl.org/a7c1a60b-474b-42ef-4a05-08de3c92853e_cx0_cy2_cw0_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/mafiya-cinema-ulan-egizbaev/33738107.html">
# <h4 class="media-block__title media-block__title--size-2" title='"Мафия": Көкжал журналист, "көлөкөдөгү кардинал"'>
#             "Мафия": Көкжал журналист, "көлөкөдөгү кардинал"
#         </h4>
# </a>
# </div>
# </div>
# </li>
# <li class="col-xs-12 col-sm-6 col-md-3 col-lg-3 mb-grid">
# <div class="media-block">
# <a class="img-wrap img-wrap--t-spac img-wrap--size-2" href="/a/ene-tiline-kueyuep-eki-elge-koepueroe-bolgon-mukhtar-shakhanov/33736339.html" title="Эне тилине күйүп, эки элге көпүрө болгон Мухтар Шаханов">
# <div class="thumb thumb16_9">
# <noscript class="nojs-img">
# <img alt="Мухтар Шаханов (солдо), Чыңгыз Айтматов (оңдо) жана профессор Илзе Циртаутас. “Ысык-Көл шеринеси”, Кыргызстан. 18.7.1997." src="https://gdb.rferl.org/28E4EBC0-9FE0-4E35-AED4-67B070E72FF2_cx8_cy10_cw87_w160_r1.jpg"/>
# </noscript>
# <img alt="Мухтар Шаханов (солдо), Чыңгыз Айтматов (оңдо) жана профессор Илзе Циртаутас. “Ысык-Көл шеринеси”, Кыргызстан. 18.7.1997." class="" data-src="https://gdb.rferl.org/28E4EBC0-9FE0-4E35-AED4-67B070E72FF2_cx8_cy10_cw87_w100_r1.jpg" src=""/>
# </div>
# </a>
# <div class="media-block__content">
# <a href="/a/ene-tiline-kueyuep-eki-elge-koepueroe-bolgon-mukhtar-shakhanov/33736339.html">
# <h4 class="media-block__title media-block__title--size-2" title="Эне тилине күйүп, эки элге көпүрө болгон Мухтар Шаханов">
#             Эне тилине күйүп, эки элге көпүрө болгон Мухтар Шаханов
#         </h4>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-14503_122">
# <div class="row" id="wrowblock-14503_123">
# <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9" id="wrowblock-14503_124">
# <div class="row" id="wrowblock-14503_126">
# <div class="col-xs-12 col-sm-12 col-md-8 col-lg-8 wg-area-2c" id="wrowblock-14503_127">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-14503_128">
# </div>
# </div>
# <div class="row" id="wrowblock-14503_129">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-3c" id="wrowblock-14503_130">
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-14503_125">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-13658_122">
# <div class="row" id="wrowblock-13658_123">
# <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9" id="wrowblock-13658_124">
# <div class="row" id="wrowblock-13658_126">
# <div class="col-xs-12 col-sm-12 col-md-8 col-lg-8 wg-area-2c" id="wrowblock-13658_127">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-13658_128">
# </div>
# </div>
# <div class="row" id="wrowblock-13658_129">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-3c" id="wrowblock-13658_130">
# </div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-12 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-13658_125">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-12163_76">
# <div class="row sm-clear-third" id="wrowblock-12163_64">
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12163_65">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12163_66">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12163_67">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-12163_68">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-13659_74">
# <div class="row" id="wrowblock-13659_52">
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-13659_53">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-13659_54">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-12602_74">
# <div class="row" id="wrowblock-12602_52">
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-12602_53">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-6 col-lg-6 wg-area-2c" id="wrowblock-12602_54">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-12718_73">
# <div class="row" id="wrowblock-12718_49">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-12718_50">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-56238_13">
# <div class="row" id="wrowblock-56238_14">
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56238_15">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56238_16">
# </div>
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4 wg-area-1c" id="wrowblock-56238_17">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-56239_9">
# <div class="row" id="wrowblock-56239_10">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-3c" id="wrowblock-56239_11">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-61424_73">
# <div class="row" id="wrowblock-61424_49">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 wg-area-4c" id="wrowblock-61424_50">
# </div>
# </div>
# </div>
# <div class="container" id="wrowblock-61425_76">
# <div class="row sm-clear-third" id="wrowblock-61425_64">
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-61425_65">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-61425_66">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-61425_67">
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 col-lg-3 wg-area-1c" id="wrowblock-61425_68">
# </div>
# </div>
# </div>
# </div>
# <footer role="contentinfo">
# <div class="foot" id="foot">
# <div class="container">
# <div class="foot-nav collapsed" id="foot-nav">
# <div class="menu">
# <ul class="items">
# <li class="socials block-socials">
# <span class="handler" id="socials-handler">
#                                             Онлайн шерине
#                                         </span>
# <div class="inner">
# <ul class="subitems follow">
# <li>
# <a class="btn btn--rounded js-social-btn btn-facebook" data-analytics-text="follow_on_facebook" href="https://www.facebook.com/azattyk.org" rel="noopener" target="_blank" title="Фейсбуктан караңыз">
# <span class="ico ico-facebook-alt ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-twitter" data-analytics-text="follow_on_twitter" href="https://twitter.com/Azattyk_Radiosu" rel="noopener" target="_blank" title="Твиттерден караңыз">
# <span class="ico ico-twitter ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-youtube" data-analytics-text="follow_on_youtube" href="https://www.youtube.com/user/AzattykUnalgysy" rel="noopener" target="_blank" title="Ютубдан көрүңүз">
# <span class="ico ico-youtube ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-telegram" data-analytics-text="follow_on_telegram" href="https://telegram.me/Azattyk_radiosu" rel="noopener" target="_blank" title="Телеграмдан окуңуз">
# <span class="ico ico-telegram ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-g-news" data-analytics-text="follow_on_google_news" href="https://news.google.com/publications/CAAqBwgKMMH4gQIwvrcX?hl=ru&amp; " rel="noopener" target="_blank" title="Google News аркылуу окуңуз">
# <span class="ico ico-google-news ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-soundcloud" data-analytics-text="follow_on_soundcloud" href="https://soundcloud.com/azattyk-audio" rel="noopener" target="_blank" title="Follow us on SoundCloud">
# <span class="ico ico-soundcloud ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-instagram" data-analytics-text="follow_on_instagram" href="https://www.instagram.com/azattyk.kg/" rel="noopener" target="_blank" title="Инстаграмдан көрүңүз">
# <span class="ico ico-instagram ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-whatsapp visible-xs-inline-block visible-sm-inline-block" data-analytics-text="follow_on_whatsapp" href="https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E" rel="noopener" target="_blank" title="Follow on WhatsApp">
# <span class="ico ico-whatsapp ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-whatsapp visible-md-inline-block visible-lg-inline-block" data-analytics-text="follow_on_whatsapp_desktop" href="https://www.whatsapp.com/channel/0029VaEfXksHbFV2MNnL1I3E" rel="noopener" target="_blank" title="Follow on WhatsApp">
# <span class="ico ico-whatsapp ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-rss" data-analytics-text="follow_on_rss" href="/rssfeeds" title="RSS">
# <span class="ico ico-rss ico--rounded"></span>
# </a>
# </li>
# <li>
# <a class="btn btn--rounded js-social-btn btn-podcast" data-analytics-text="follow_on_podcast" href="/podcasts" title="Подкаст">
# <span class="ico ico-podcast ico--rounded"></span>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="block-primary collapsed collapsible item">
# <span class="handler">
#                 Биз жөнүндө
#                 <span class="ico ico-chevron-up" title="close tab"></span>
# <span class="ico ico-chevron-down" title="open tab"></span>
# <span class="ico ico-plus" title="add"></span>
# <span class="ico ico-minus" title="remove"></span>
# </span>
# <div class="inner">
# <ul class="subitems">
# <li class="subitem">
# <a class="handler" href="https://www.azattyk.org/p/8992.html" title="Блоктолгон сайтты ачуу">Блоктолгон сайтты ачуу</a>
# </li>
# <li class="subitem">
# <a class="handler" href="/p/5274.html" title="Биз жөнүндө">Биз жөнүндө</a>
# </li>
# <li class="subitem">
# <a class="handler" href="/p/4372.html" title="Эрежелер">Эрежелер</a>
# </li>
# <li class="subitem">
# <a class="handler" href="/p/5402.html" title="Азаттык - WhatsApp">Азаттык - WhatsApp</a>
# </li>
# <li class="subitem">
# <a class="handler" href="https://www.azattyk.org/a/28413819.html" title="Азаттыктын тиркемеси">Азаттыктын тиркемеси</a>
# </li>
# <li class="subitem">
# <a class="handler" href="https://rus.azattyk.org/jobs.html" rel="noopener" target="_blank" title="Вакансиялар">Вакансиялар</a>
# </li>
# <li class="subitem">
# <a class="handler" href="https://www.azattyk.org/p/9053.html" title='"Азаттык" менен байланыш'>"Азаттык" менен байланыш</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="block-primary collapsed collapsible item">
# <span class="handler">
#                 "Азаттыктын" сандыгы
#                 <span class="ico ico-chevron-up" title="close tab"></span>
# <span class="ico ico-chevron-down" title="open tab"></span>
# <span class="ico ico-plus" title="add"></span>
# <span class="ico ico-minus" title="remove"></span>
# </span>
# <div class="inner">
# <ul class="subitems">
# <li class="subitem">
# <a class="handler" href="/p/5452.html" title="Тилим - дилим">Тилим - дилим</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="foot__item foot__item--copyrights">
# <p class="copyright">Азаттык үналгысы © 2026 RFE/RL, Inc. Бардык укуктар корголгон.</p>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <script defer="" src="https://cdn.onesignal.com/sdks/web/v16/OneSignalSDK.page.js"></script>
# <script>
#
# if (!isPreviewPage) {
#
#   window.OneSignalDeferred = window.OneSignalDeferred || [];
#
#   OneSignalDeferred.push(function(OneSignal) {
#
#     OneSignal.init({
#
#       appId: "3525e4c0-4751-4122-bd00-60b5b643df40",
#
#     });
#
#   });
#
# }
#
# </script> <script defer="" src="/Scripts/responsive/serviceWorkerInstall.js?cb=382"></script>
# <script type="text/javascript">
#
#         // opera mini - disable ico font
#         if (navigator.userAgent.match(/Opera Mini/i)) {
#             document.getElementsByTagName("body")[0].className += " can-not-ff";
#         }
#
#         // mobile browsers test
#         if (typeof RFE !== 'undefined' && RFE.isMobile) {
#             if (RFE.isMobile.any()) {
#                 document.getElementsByTagName("body")[0].className += " is-mobile";
#             }
#             else {
#                 document.getElementsByTagName("body")[0].className += " is-not-mobile";
#             }
#         }
#     </script>
# <script src="/conf.js?x=382" type="text/javascript"></script>
# <div class="responsive-indicator">
# <div class="visible-xs-block">XS</div>
# <div class="visible-sm-block">SM</div>
# <div class="visible-md-block">MD</div>
# <div class="visible-lg-block">LG</div>
# </div>
# <script type="text/javascript">
#             var bar_data = {
#   "apiId": "5341",
#   "apiType": "2",
#   "isEmbedded": "0",
#   "culture": "ky-KG",
#   "cookieName": "cmsLoggedIn",
#   "cookieDomain": "www.azattyk.org"
# };
#         </script>
# <div id="scriptLoaderTarget" style="display:none;contain:strict;"></div>
# </body>
# </html>

# %%
with open("page.html", "w", encoding="utf-8") as f:
    f.write(soup.prettify())
